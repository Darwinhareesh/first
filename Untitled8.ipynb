# %% [markdown]
# <a href="https://colab.research.google.com/github/Darwinhareesh/first/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/drive/MyDrive/mobile_dataset.csv')

# %%
data
# Out:
#                            Product Name Actual price Discount price  Stars  \
# 0       Apple iPhone 15 (Green, 128 GB)      ₹79,600        ₹65,999    4.6
# 1        Apple iPhone 15 (Blue, 128 GB)      ₹79,600        ₹65,999    4.6
# 2       Apple iPhone 15 (Black, 128 GB)      ₹79,600        ₹65,999    4.6
# 3    OnePlus N20 SE (JADE WAVE, 128 GB)      ₹19,999        ₹11,489    4.0
# 4    OnePlus N20 SE (BLUE OASIS, 64 GB)      ₹16,999        ₹12,999    4.0
# ..                                  ...          ...            ...    ...
# 979                        Kechaoda A27       ₹1,499           ₹967    4.0
# 980                        Kechaoda A27       ₹1,499           ₹975    4.0
# 981                        Kechaoda A27       ₹1,499           ₹975    4.0
# 982                        Kechaoda A27       ₹1,499           ₹930    4.0
# 983                        Kechaoda A27       ₹1,499           ₹967    4.0
#
# ...

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                          Product Name Actual price Discount price  Stars  \
# 0     Apple iPhone 15 (Green, 128 GB)      ₹79,600        ₹65,999    4.6
# 1      Apple iPhone 15 (Blue, 128 GB)      ₹79,600        ₹65,999    4.6
# 2     Apple iPhone 15 (Black, 128 GB)      ₹79,600        ₹65,999    4.6
# 3  OnePlus N20 SE (JADE WAVE, 128 GB)      ₹19,999        ₹11,489    4.0
# 4  OnePlus N20 SE (BLUE OASIS, 64 GB)      ₹16,999        ₹12,999    4.0
#
#            Rating        Reviews RAM (GB) Storage (GB)  Display Size (inch)  \
# 0  44,793 Ratings  2,402 Reviews      NIL          128                 6.10
# 1  44,793 Ratings  2,402 Reviews      NIL          128                 6.10
# 2  44,793 Ratings  2,402 Reviews      NIL          128                 6.10
# 3   1,005 Ratings     41 Reviews        4          128                 6.56
# 4   1,005 Ratings     41 Reviews        4           64                 6.56
#
#         Camera                                        Description  \
# ...

# %%
df.columns
# Out:
# Index(['Product Name', 'Actual price', 'Discount price', 'Stars', 'Rating',
#        'Reviews', 'RAM (GB)', 'Storage (GB)', 'Display Size (inch)', 'Camera',
#        'Description', 'Link'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product Name         984 non-null    object
#  1   Actual price         984 non-null    object
#  2   Discount price       984 non-null    object
#  3   Stars                984 non-null    float64
#  4   Rating               984 non-null    object
#  5   Reviews              984 non-null    object
#  6   RAM (GB)             984 non-null    object
#  7   Storage (GB)         984 non-null    object
#  8   Display Size (inch)  984 non-null    float64
#  9   Camera               908 non-null    object
#  10  Description          984 non-null    object
#  11  Link                 984 non-null    object
# dtypes: float64(2), object(10)
# memory usage: 92.4+ KB

# %%
df.isnull().sum()
# Out:
# Product Name            0
# Actual price            0
# Discount price          0
# Stars                   0
# Rating                  0
# Reviews                 0
# RAM (GB)                0
# Storage (GB)            0
# Display Size (inch)     0
# Camera                 76
# Description             0
# Link                    0
# dtype: int64

# %%
df['Camera']
# Out:
# 0      48MP + 12MP
# 1      48MP + 12MP
# 2      48MP + 12MP
# 3            50MP
# 4            50MP
#           ...
# 979    0MP | 0MP
# 980            NaN
# 981            NaN
# 982    0MP | 0MP
# 983    0MP | 0MP
# Name: Camera, Length: 984, dtype: object

# %%
new_df = df.replace('NIL',np.nan)

# %%
new_df.isnull().sum()
# Out:
# Product Name             0
# Actual price            54
# Discount price           0
# Stars                    0
# Rating                   0
# Reviews                  0
# RAM (GB)               161
# Storage (GB)           109
# Display Size (inch)      0
# Camera                  76
# Description              0
# Link                     0
# dtype: int64

# %%
(df['Actual price']=='NIL').sum()
# Out:
# 54

# %%
df['Actual price']
# Out:
# 0      ₹79,600
# 1      ₹79,600
# 2      ₹79,600
# 3      ₹19,999
# 4      ₹16,999
#         ...
# 979     ₹1,499
# 980     ₹1,499
# 981     ₹1,499
# 982     ₹1,499
# 983     ₹1,499
# Name: Actual price, Length: 984, dtype: object

# %%
new_df['Actual price'] = new_df['Actual price'].replace('[₹,]', '', regex=True)

# Convert to numeric, coercing errors (like 'NaN') to NaN
new_df['Actual price'] = pd.to_numeric(new_df['Actual price'], errors='coerce')

# Optionally, drop or fill NaN values before converting to int
new_df['Actual price'] = new_df['Actual price'].fillna(0).astype(int)

# %%
new_df['Discount price'] = new_df['Discount price'].replace('[₹,]', '', regex=True)

# Convert to numeric, coercing errors (like 'NaN') to NaN
new_df['Discount price'] = pd.to_numeric(new_df['Discount price'], errors='coerce')

# Optionally, drop or fill NaN values before converting to int
new_df['Discount price'] = new_df['Discount price'].fillna(0).astype(int)

# %%
new_df
# Out:
#                            Product Name  Actual price  Discount price  Stars  \
# 0       Apple iPhone 15 (Green, 128 GB)         79600           65999    4.6
# 1        Apple iPhone 15 (Blue, 128 GB)         79600           65999    4.6
# 2       Apple iPhone 15 (Black, 128 GB)         79600           65999    4.6
# 3    OnePlus N20 SE (JADE WAVE, 128 GB)         19999           11489    4.0
# 4    OnePlus N20 SE (BLUE OASIS, 64 GB)         16999           12999    4.0
# ..                                  ...           ...             ...    ...
# 979                        Kechaoda A27          1499             967    4.0
# 980                        Kechaoda A27          1499             975    4.0
# 981                        Kechaoda A27          1499             975    4.0
# 982                        Kechaoda A27          1499             930    4.0
# 983                        Kechaoda A27          1499             967    4.0
#
# ...

# %%
new_df = new_df.dropna()

# %%
new_df.isnull().sum()
# Out:
# Product Name           0
# Actual price           0
# Discount price         0
# Stars                  0
# Rating                 0
# Reviews                0
# RAM (GB)               0
# Storage (GB)           0
# Display Size (inch)    0
# Camera                 0
# Description            0
# Link                   0
# dtype: int64

# %%
df.iloc[400]
# Out:
# Product Name           LAVA Yuva 3 with Dual Sim|5000 mAh Battery|13M...
# Actual price                                                         NIL
# Discount price
# Stars                                                                4.1
# Rating                                                       203 Ratings
# Reviews                                                       12 Reviews
# RAM (GB)                                                               4
# Storage (GB)                                                          64
# Display Size (inch)                                                  6.5
# Camera                                                             13MP
# Description            4 GB RAM | 64 GB ROM | Expandable Upto 512 GB1...
# Link                   https://www.flipkart.com/lava-yuva-3-dual-sim-...
# Name: 400, dtype: object

# %%
new_df[new_df['Discount price'] == 0]
# Out:
#                                           Product Name  Actual price  \
# 400  LAVA Yuva 3 with Dual Sim|5000 mAh Battery|13M...             0
# 897           REDMI Note 13 5G (Stealth Black, 128 GB)             0
# 898           REDMI Note 13 5G (Stealth Black, 256 GB)             0
#
#      Discount price  Stars          Rating      Reviews RAM (GB) Storage (GB)  \
# 400               0    4.1     203 Ratings   12 Reviews        4           64
# 897               0    4.2  10,801 Ratings  650 Reviews        6          128
# 898               0    4.1   2,107 Ratings  130 Reviews       12          256
#
#      Display Size (inch)  Camera  \
# 400                 6.50   13MP
# 897                 6.67  108MP
# 898                 6.67  108MP
#
#                                            Description  \
# 400  4 GB RAM | 64 GB ROM | Expandable Upto 512 GB1...
# 897  6 GB RAM | 128 GB ROM16.94 cm (6.67 inch) Full...
# 898  12 GB RAM | 256 GB ROM16.94 cm (6.67 inch) Dis...
#
# ...

# %%
new_df.loc[new_df['Stars']>4.0]
# Out:
#                                    Product Name  Actual price  Discount price  \
# 5               OnePlus 12R (Cool Blue, 128 GB)         39999           38989
# 6    SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)         17490           10990
# 7         CMF by Nothing Phone 1 (Blue, 128 GB)         19999           15999
# 8         CMF by Nothing Phone 1 (Blue, 128 GB)         21999           17999
# 9         vivo Y200e 5G (Black Diamond, 128 GB)         25999           20999
# ..                                          ...           ...             ...
# 948          Motorola G60 (Soft Silver, 128 GB)         21999           14999
# 955        vivo X70 Pro+ (Enigma Black, 256 GB)         84990           48999
# 956        vivo X70 Pro+ (Enigma Black, 256 GB)         84990           48999
# 957          Micromax IN Note 1 (Green, 128 GB)         16999           10999
# 967    Motorola G60 (Frosted Champagne, 128 GB)         21999           14999
#
# ...

# %%
new_df.sort_values(by='Discount price',inplace=True)
# Out:
# <ipython-input-23-8f3aa40fe74b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.sort_values(by='Discount price',inplace=True)

# %%
new_df
# Out:
#                                           Product Name  Actual price  \
# 400  LAVA Yuva 3 with Dual Sim|5000 mAh Battery|13M...             0
# 898           REDMI Note 13 5G (Stealth Black, 256 GB)             0
# 897           REDMI Note 13 5G (Stealth Black, 128 GB)             0
# 647                                      itel Circle 1          1899
# 571                                      itel Circle 1          1899
# ..                                                 ...           ...
# 39   SAMSUNG Galaxy S24 Ultra 5G (Titanium Black, 2...        134999
# 114  SAMSUNG Galaxy S24 Ultra 5G (Titanium Violet, ...        134999
# 695           SAMSUNG Galaxy Z Fold6 5G (Navy, 256 GB)             0
# 154  SAMSUNG Galaxy Z Fold6 5G (Silver Shadow, 256 GB)             0
# 155  SAMSUNG Galaxy Z Fold6 5G (Silver Shadow, 512 GB)             0
#
#      Discount price  Stars          Rating      Reviews RAM (GB) Storage (GB)  \
# ...

# %%
grp = new_df.groupby('RAM (GB)')

# %%
grp['Discount price'].mean()
# Out:
# RAM (GB)
# 12       41245.960000
# 16       63742.333333
# 2         5874.000000
# 3         7873.333333
# 32        1348.000000
# 4         9825.918367
# 46875     5049.000000
# 6        13321.095652
# 8        24678.604396
# Name: Discount price, dtype: float64

# %%
new_df['Reviews'].str.replace('Reviews','')
# Out:
# 400     12
# 898    130
# 897    650
# 647     24
# 571     24
#        ...
# 39     244
# 114    244
# 695      2
# 154      2
# 155      2
# Name: Reviews, Length: 782, dtype: object

# %%
new_df['Reviews']=new_df['Reviews'].str.replace('Reviews','')
# Out:
# <ipython-input-28-7a5b02e1382a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Reviews']=new_df['Reviews'].str.replace('Reviews','')

# %%
new_df
# Out:
#                                           Product Name  Actual price  \
# 400  LAVA Yuva 3 with Dual Sim|5000 mAh Battery|13M...             0
# 898           REDMI Note 13 5G (Stealth Black, 256 GB)             0
# 897           REDMI Note 13 5G (Stealth Black, 128 GB)             0
# 647                                      itel Circle 1          1899
# 571                                      itel Circle 1          1899
# ..                                                 ...           ...
# 39   SAMSUNG Galaxy S24 Ultra 5G (Titanium Black, 2...        134999
# 114  SAMSUNG Galaxy S24 Ultra 5G (Titanium Violet, ...        134999
# 695           SAMSUNG Galaxy Z Fold6 5G (Navy, 256 GB)             0
# 154  SAMSUNG Galaxy Z Fold6 5G (Silver Shadow, 256 GB)             0
# 155  SAMSUNG Galaxy Z Fold6 5G (Silver Shadow, 512 GB)             0
#
#      Discount price  Stars          Rating Reviews RAM (GB) Storage (GB)  \
# ...

# %%
df.groupby('Product Name')['Reviews'].sum()
# Out:
# Product Name
# Apple iPhone 12 (Black, 256 GB)                                     13,889 Reviews
# Apple iPhone 12 (Black, 64 GB)                                      13,889 Reviews
# Apple iPhone 12 (Blue, 128 GB)                                      13,889 Reviews
# Apple iPhone 13 (Blue, 128 GB)                                      13,690 Reviews
# Apple iPhone 13 (Blue, 256 GB)                        13,690 Reviews13,690 Reviews
#                                                             ...
# vivo Y27 (Sea Blue, 128 GB)                                            101 Reviews
# vivo Y28 5G (Crystal Purple, 128 GB)      28 Reviews28 Reviews15 Reviews12 Reviews
# vivo Y28 5G (Glitter Aqua, 128 GB)                                      15 Reviews
# vivo Y58 5G (Himalayan Blue, 128 GB)                                     0 Reviews
# vivo Y58 5G (Sundarbans Green, 128 GB)                                   0 Reviews
# Name: Reviews, Length: 657, dtype: object

# %%
df['Rating']=df['Rating'].str.replace('Ratings','').str.replace(',','')

# %%
df['Rating']=pd.to_numeric(df['Rating'])

# %%
new_df
# Out:
#                                           Product Name  Actual price  \
# 400  LAVA Yuva 3 with Dual Sim|5000 mAh Battery|13M...             0
# 898           REDMI Note 13 5G (Stealth Black, 256 GB)             0
# 897           REDMI Note 13 5G (Stealth Black, 128 GB)             0
# 647                                      itel Circle 1          1899
# 571                                      itel Circle 1          1899
# ..                                                 ...           ...
# 39   SAMSUNG Galaxy S24 Ultra 5G (Titanium Black, 2...        134999
# 114  SAMSUNG Galaxy S24 Ultra 5G (Titanium Violet, ...        134999
# 695           SAMSUNG Galaxy Z Fold6 5G (Navy, 256 GB)             0
# 154  SAMSUNG Galaxy Z Fold6 5G (Silver Shadow, 256 GB)             0
# 155  SAMSUNG Galaxy Z Fold6 5G (Silver Shadow, 512 GB)             0
#
#      Discount price  Stars          Rating Reviews RAM (GB) Storage (GB)  \
# ...

# %%
alt = pd.read_csv('/content/drive/MyDrive/mobile_dataset.csv')

# %%
nd = pd.DataFrame(alt)

# %%
k=pd.read_csv(r"/content/drive/MyDrive/battery.csv")

# %%
pd.merge(nd,k,on='Product Name',how = 'left')
# Out:
#                             Product Name Actual price Discount price  Stars  \
# 0        Apple iPhone 15 (Green, 128 GB)      ₹79,600        ₹65,999    4.6
# 1         Apple iPhone 15 (Blue, 128 GB)      ₹79,600        ₹65,999    4.6
# 2        Apple iPhone 15 (Black, 128 GB)      ₹79,600        ₹65,999    4.6
# 3     OnePlus N20 SE (JADE WAVE, 128 GB)      ₹19,999        ₹11,489    4.0
# 4     OnePlus N20 SE (BLUE OASIS, 64 GB)      ₹16,999        ₹12,999    4.0
# ...                                  ...          ...            ...    ...
# 2783                        Kechaoda A27       ₹1,499           ₹967    4.0
# 2784                        Kechaoda A27       ₹1,499           ₹967    4.0
# 2785                        Kechaoda A27       ₹1,499           ₹967    4.0
# 2786                        Kechaoda A27       ₹1,499           ₹967    4.0
# 2787                        Kechaoda A27       ₹1,499           ₹967    4.0
#
# ...

# %%
new_df[new_df['RAM (GB)']=='46875']
# Out:
#                                           Product Name Actual price  \
# 803  Nokia 2660 Flip 4G Volte Red keypad Mobile wit...       ₹5,899
# 804  Nokia 2660 Flip 4G Volte Red keypad Mobile wit...       ₹5,899
#
#     Discount price  Stars  Rating     Reviews RAM (GB) Storage (GB)  \
# 803         ₹5,049    4.0     468  23 Reviews    46875          125
# 804         ₹5,049    4.0     468  23 Reviews    46875          125
#
#      Display Size (inch) Camera  \
# 803                  2.8   3MP
# 804                  2.8   3MP
#
#                                            Description  \
# 803  0.046875 GB RAM | 0.125 GB ROM7.11 cm (2.8 inc...
# 804  0.046875 GB RAM | 0.125 GB ROM7.11 cm (2.8 inc...
#
#                                                   Link
# 803  https://www.flipkart.com/nokia-2660-flip-4g-vo...
# 804  https://www.flipkart.com/nokia-2660-flip-4g-vo...

# %%
import matplotlib.pyplot as plt
new_df.groupby('RAM (GB)')['Stars'].mean().plot(kind='bar')
plt.ylabel('Average Stars Rating')
plt.title('Average Stars Rating by RAM (GB)')
plt.show()

# %%
new_df['RAM (GB)']=pd.to_numeric(new_df['RAM (GB)'])
# Out:
# <ipython-input-40-555bac39bfb2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['RAM (GB)']=pd.to_numeric(new_df['RAM (GB)'])

# %%
new_df[new_df['RAM (GB)']==46875]
# Out:
#                                           Product Name  Actual price  \
# 804  Nokia 2660 Flip 4G Volte Red keypad Mobile wit...          5899
# 803  Nokia 2660 Flip 4G Volte Red keypad Mobile wit...          5899
#
#      Discount price  Stars       Rating Reviews  RAM (GB) Storage (GB)  \
# 804            5049    4.0  468 Ratings     23      46875          125
# 803            5049    4.0  468 Ratings     23      46875          125
#
#      Display Size (inch) Camera  \
# 804                  2.8   3MP
# 803                  2.8   3MP
#
#                                            Description  \
# 804  0.046875 GB RAM | 0.125 GB ROM7.11 cm (2.8 inc...
# 803  0.046875 GB RAM | 0.125 GB ROM7.11 cm (2.8 inc...
#
#                                                   Link
# 804  https://www.flipkart.com/nokia-2660-flip-4g-vo...
# 803  https://www.flipkart.com/nokia-2660-flip-4g-vo...

# %%
q1 = new_df['RAM (GB)'].quantile(0.25)
q3 = new_df['RAM (GB)'].quantile(0.75)
iqr = q3 - q1
low = q1 - 1.5 * iqr
up = q3 + 1.5 * iqr
outliers = new_df[(new_df['RAM (GB)'] < low) | (new_df['RAM (GB)'] > up)]

# %%
import matplotlib.pyplot as plt
new_df.groupby('RAM (GB)')['Stars'].mean().plot(kind='bar')
plt.ylabel('Average Stars Rating')
plt.title('Average Stars Rating by RAM (GB)')
plt.show()

# %%
new_df['Storage (GB)']=pd.to_numeric(new_df['Storage (GB)'])
# Out:
# <ipython-input-44-456447998684>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Storage (GB)']=pd.to_numeric(new_df['Storage (GB)'])

# %%
new_df[(new_df['Storage (GB)']>128) & (new_df['Stars']>4.0)]
# Out:
#                                           Product Name  Actual price  \
# 898           REDMI Note 13 5G (Stealth Black, 256 GB)             0
# 191                  itel A70 (Briiliant Gold, 256 GB)         10999
# 166                      itel A70 (Azure Blue, 256 GB)         10999
# 764                     POCO C65 (Pastel Blue, 256 GB)         13499
# 541                     POCO C65 (Matte Black, 256 GB)         13499
# ..                                                 ...           ...
# 39   SAMSUNG Galaxy S24 Ultra 5G (Titanium Black, 2...        134999
# 114  SAMSUNG Galaxy S24 Ultra 5G (Titanium Violet, ...        134999
# 695           SAMSUNG Galaxy Z Fold6 5G (Navy, 256 GB)             0
# 154  SAMSUNG Galaxy Z Fold6 5G (Silver Shadow, 256 GB)             0
# 155  SAMSUNG Galaxy Z Fold6 5G (Silver Shadow, 512 GB)             0
#
#      Discount price  Stars         Rating Reviews  RAM (GB)  Storage (GB)  \
# ...

# %%
clean = new_df.drop_duplicates(subset='Product Name')

# %%
clean
# Out:
#                                           Product Name  Actual price  \
# 400  LAVA Yuva 3 with Dual Sim|5000 mAh Battery|13M...             0
# 898           REDMI Note 13 5G (Stealth Black, 256 GB)             0
# 897           REDMI Note 13 5G (Stealth Black, 128 GB)             0
# 647                                      itel Circle 1          1899
# 913                  itel A23s (Sapphire Black, 32 GB)          5999
# ..                                                 ...           ...
# 39   SAMSUNG Galaxy S24 Ultra 5G (Titanium Black, 2...        134999
# 114  SAMSUNG Galaxy S24 Ultra 5G (Titanium Violet, ...        134999
# 695           SAMSUNG Galaxy Z Fold6 5G (Navy, 256 GB)             0
# 154  SAMSUNG Galaxy Z Fold6 5G (Silver Shadow, 256 GB)             0
# 155  SAMSUNG Galaxy Z Fold6 5G (Silver Shadow, 512 GB)             0
#
#      Discount price  Stars          Rating Reviews  RAM (GB)  Storage (GB)  \
# ...

# %%
new_df.to_csv('clean.csv' ,index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxplot(x=df['Discount price'])
plt.title('Boxplot of Discount Price')
plt.show()

# %%
q1 = new_df['Discount price'].quantile(0.25)
q3 = new_df['Discount price'].quantile(0.75)
iqr = q3 - q1
low = q1 - 1.5 * iqr
up = q3 + 1.5 * iqr
outliers = new_df[(new_df['Discount price'] < low) | (new_df['Discount price'] > up)]

# %%
outliers
# Out:
#                                           Product Name  Actual price  \
# 647                                      itel Circle 1          1899
# 571                                      itel Circle 1          1899
# 913                  itel A23s (Sapphire Black, 32 GB)          5999
# 804  Nokia 2660 Flip 4G Volte Red keypad Mobile wit...          5899
# 803  Nokia 2660 Flip 4G Volte Red keypad Mobile wit...          5899
# ..                                                 ...           ...
# 355                OnePlus Open (Emerald Dusk, 512 GB)        149999
# 292        SAMSUNG Galaxy S23 Ultra 5G (Cream, 256 GB)        149999
# 871  SAMSUNG Galaxy S24 Ultra 5G (Titanium Gray, 25...        134999
# 39   SAMSUNG Galaxy S24 Ultra 5G (Titanium Black, 2...        134999
# 114  SAMSUNG Galaxy S24 Ultra 5G (Titanium Violet, ...        134999
#
#      Discount price  Stars         Rating Reviews  RAM (GB)  Storage (GB)  \
# ...

# %%
pivot_table = new_df.pivot_table(values='Discount price', index='RAM (GB)', columns='Storage (GB)', aggfunc='mean')

# %%
pivot_table
# Out:
# Storage (GB)          32            64      125           128           256  \
# RAM (GB)
# 2             5811.500000   5999.000000     NaN           NaN           NaN
# 3             9179.666667   7220.166667     NaN           NaN           NaN
# 4                     NaN   8168.365385     NaN  10807.064516   7299.000000
# 6                     NaN  10999.000000     NaN  13362.194690           NaN
# 8                     NaN           NaN     NaN  23161.649215  25983.360465
# 12                    NaN           NaN     NaN  45999.000000  40454.836957
# 16                    NaN           NaN     NaN           NaN  41071.200000
# 32            1348.000000           NaN     NaN           NaN           NaN
# 46875                 NaN           NaN  5049.0           NaN           NaN
#
# Storage (GB)          512
# RAM (GB)
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 6                     NaN
# 8             89999.00000
# ...

# %%
new_df['Stars'].fillna(new_df['Stars'].mean(), inplace=True)
# Out:
# <ipython-input-55-f1e68e3f875e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Stars'].fillna(new_df['Stars'].mean(), inplace=True)

# %%
new_df
# Out:
#                                           Product Name  Actual price  \
# 400  LAVA Yuva 3 with Dual Sim|5000 mAh Battery|13M...             0
# 898           REDMI Note 13 5G (Stealth Black, 256 GB)             0
# 897           REDMI Note 13 5G (Stealth Black, 128 GB)             0
# 647                                      itel Circle 1          1899
# 571                                      itel Circle 1          1899
# ..                                                 ...           ...
# 39   SAMSUNG Galaxy S24 Ultra 5G (Titanium Black, 2...        134999
# 114  SAMSUNG Galaxy S24 Ultra 5G (Titanium Violet, ...        134999
# 695           SAMSUNG Galaxy Z Fold6 5G (Navy, 256 GB)             0
# 154  SAMSUNG Galaxy Z Fold6 5G (Silver Shadow, 256 GB)             0
# 155  SAMSUNG Galaxy Z Fold6 5G (Silver Shadow, 512 GB)             0
#
#      Discount price  Stars          Rating Reviews  RAM (GB)  Storage (GB)  \
# ...

# %%
Max = new_df['Discount price'].max()
Max
# Out:
# 176999

# %%
new_df['Discount price'].mean()
# Out:
# 23016.494884910488

# %%
from re import X
def price_category(x):
    if X >40000 :
        return 'High-end'
    elif x > 30000:
        return 'Mid-range'
    else:
        return 'Budget'

new_df['Category'] = new_df['Discount price'].apply(price_category)
# Out:
# <ipython-input-59-c1b5e60cd8a8>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Category'] = new_df['Discount price'].apply(price_category)

# %%
new_df['Category']
# Out:
# 400       Budget
# 898       Budget
# 897       Budget
# 647       Budget
# 571       Budget
#          ...
# 39     Mid-range
# 114    Mid-range
# 695    Mid-range
# 154    Mid-range
# 155    Mid-range
# Name: Category, Length: 782, dtype: object

# %%
new_df = new_df[new_df['Actual price'] != 0]
new_df
# Out:
#                                           Product Name  Actual price  \
# 647                                      itel Circle 1          1899
# 571                                      itel Circle 1          1899
# 913                  itel A23s (Sapphire Black, 32 GB)          5999
# 804  Nokia 2660 Flip 4G Volte Red keypad Mobile wit...          5899
# 803  Nokia 2660 Flip 4G Volte Red keypad Mobile wit...          5899
# ..                                                 ...           ...
# 355                OnePlus Open (Emerald Dusk, 512 GB)        149999
# 292        SAMSUNG Galaxy S23 Ultra 5G (Cream, 256 GB)        149999
# 871  SAMSUNG Galaxy S24 Ultra 5G (Titanium Gray, 25...        134999
# 39   SAMSUNG Galaxy S24 Ultra 5G (Titanium Black, 2...        134999
# 114  SAMSUNG Galaxy S24 Ultra 5G (Titanium Violet, ...        134999
#
#      Discount price  Stars         Rating Reviews  RAM (GB)  Storage (GB)  \
# ...

# %%
Mean = new_df['Discount price'].mean()
Mean
# Out:
# 21183.84741144414

# %%
tolerance = 0.05 * Mean  # 5% of the mean price

lower_bound = Mean - tolerance
upper_bound = Mean + tolerance

# %%
new_df[(new_df['Discount price'] >= lower_bound) & (new_df['Discount price'] <= upper_bound)]
# Out:
#                                         Product Name  Actual price  \
# 372  OnePlus Nord CE4 lite 5G (ULTRA ORANGE, 128 GB)         20999
# 371  OnePlus Nord CE4 lite 5G (ULTRA ORANGE, 128 GB)         20999
# 353         OnePlus Nord CE3 5G (Aqua Surge, 128 GB)         26999
# 879           realme P1 Pro 5G (Parrot Blue, 256 GB)         25999
# 477      REDMI Note 13 5G (Chromatic Purple, 256 GB)         24999
# 655                POCO X6 5G (Skyline Blue, 256 GB)         26999
# 188          realme 12+ 5G (Navigator Beige, 128 GB)         23999
# 392           realme P1 Pro 5G (Phoenix Red, 256 GB)         25999
# 9              vivo Y200e 5G (Black Diamond, 128 GB)         25999
# 110                POCO X6 5G (Mirror Black, 256 GB)         26999
# 44              POCO X6 5G (Snowstorm White, 256 GB)         26999
# 663            realme 12+ 5G (Pioneer Green, 128 GB)         23999
# 512          vivo Y200e 5G (Saffron Delight, 128 GB)         25999
# ...

# %%
#(new_df['RAM (GB)']).dtype

# %%
#new_df.info()

# %%
#new_df['RAM (GB)'] = new_df['RAM (GB)'].astype(int)
#new_df['Storage (GB)'] = new_df['Storage (GB)'].astype(int)

# %%
#new_df.sort_values(by='RAM (GB)',ascending=False)

# %%
#new_df = new_df.loc[df['Stars']>4.0]

# %%
#new_df.sort_values(by='Discount price',inplace=True)

# %%
#new_df['Reviews']=new_df['Reviews'].str.replace('Reviews','')

# %%
#new_df.groupby('RAM (GB)')['Discount price'].mean()

# %%
#new_df.groupby('Product Name')['Reviews'].sum()

# %%
#type(new_df['Rating'])

# %%
#new_df['Rating']=new_df['Rating'].str.replace('Ratings','').str.replace(',','')

# %%
#new_df['Rating']=pd.to_numeric(new_df['Rating'])

# %%
#new_df
